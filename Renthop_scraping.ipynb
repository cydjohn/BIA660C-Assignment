# %%
import requests
import urllib
from bs4 import BeautifulSoup
import time
import numpy as np
import re
import pandas as pd
import json
# Out:
# /Users/admin/anaconda/lib/python3.6/site-packages/matplotlib/__init__.py:913: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
def house_rent(url_link):
    return 'https://www.renthop.com/search/nyc?page=' + url_link

# %%
# return each house's details

def getHouseDetail(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.content, "html.parser")
    
    #Description
    description = soup.find_all("div",{"style":"font-size: 0.90em; line-height: 140%;"})[0].text
    
    #photos
    num_photos = soup.find_all("a",{"data-lightbox" : "listing-photos-set"})
    photo_link = [] 
    for i in range(len(num_photos)):
        photo = num_photos[i]['href']
        photo_link.append(photo) # each house has its own list of photo link
    
    # Amenities
    Amenities = []
    for x in range(len(soup.find_all('td',{'style':'vertical-align: top; padding-left: 8px;'}))):
        amenities_name = soup.find_all('td',{'style':'vertical-align: top; padding-left: 8px;'})[x].text.strip()
        Amenities.append(amenities_name)
    
    #median price
   
    median_price_div = soup.find_all('div',{'style': 'text-align: center; font-size: 1.00em;'})
    if len(median_price_div)>0:
        median_price_info = soup.find_all('div',{'style': 'text-align: center; font-size: 1.00em;'})[0].text.strip()
    else:
        median_price_info = 0
        
    #transportation_name
    trans = []
    for t in range(len(soup.find_all('div',{'class':'subway_nyc'}))):
        subway_name = soup.find_all('div',{'class':'subway_nyc'})[t].text.strip()
        trans.append(subway_name)
        
    #num_transportation
    subway = soup.find_all('div',{'class':'subway_nyc'})
    num_subway = len(subway)

    
    return {"Description":description,"Median_price":median_price_info,"num_transportation": num_subway,"photo_link":photo_link,"Amenities":Amenities,"trans":trans}

# %%
# return house info on each page
price = []
listing_id = []
hopscore = []
street_address = []
neighborhoods = []
expert = []
bedroom = []
bathroom = []
description = []
median_price = []
num_transportation = []
Amenities = []
photo_link = []
trans = []
# latitude = []
# longitude = []

# here is the page 1 to page 200, 4000 samples
for x in range(1,2):
    url_page = house_rent(str(x))
    r_page = requests.get(url_page)
    soup = BeautifulSoup(r_page.content, "html.parser")
    print(soup)
#     house_data = soup.find_all("div",{"class" : "search-listing"}) #20 house listings
#     print(house_data)
    
#     for house in house_data:
#         house_id = house.get('listing_id') # each house has its own listing_id
        
#         #url for each house
#         house_url = house.find_all('a',{'class':'font-size-90 listing-title-link'},href = True)[0]['href']
#         house_detail_info = getHouseDetail(house_url) # reture dictionary 
        
#         # return values from dict
#         # description
#         description_info = house_detail_info["Description"]
#         description.append(description_info)

        
#         # median_price
        
#         median_price_info = house_detail_info["Median_price"]
#         median_price.append(median_price_info)

        
#         Amenities_info = house_detail_info["Amenities"]
#         Amenities.append(Amenities_info)
        
#         photo_link_info = house_detail_info["photo_link"]
#         photo_link.append(photo_link_info)

        
#         trans_info = house_detail_info["trans"]
#         trans.append(trans_info)
        
#         # num_transportation
#         subway_info = house_detail_info["num_transportation"]
#         num_transportation.append(subway_info)
        
#         # price
#         price_id = 'listing-{}-price'.format(house_id)
#         price_div = house.find_all('div', {'id' : price_id})[0]
#         price.append(price_div.text.strip())
        
#         # listing_id
#         listing_id.append(int(house_id))
        
#         # hopscore
#         hopscore_id = 'listing-{}-hopscore'.format(house_id)
#         hopscore_div = house.find_all('div',{'id': hopscore_id})[0]
#         hopscore.append(float(hopscore_div.text.strip()))
        
#         # street_address
#         title_id = 'listing-{}-title'.format(house_id)
#         title_a = house.find_all('a',{'id': title_id})[0]
#         title = title_a.text.strip()
#         text = 'at'
#         address_name = title[title.find(text) + len(text) + 1:]
#         street_address.append(address_name)
        
#         # bedroom
#         title_tag = title_a.text.strip()
#         #number = re.findall('\d+', title_tag)
        
#         if len(re.findall('BR',title_tag))>0:
#             number = title_tag.find('BR')-1
#             bedroom.append(title_tag[number])
#         else:
#             #only one
#             bedroom.append(1)
        
#         # bathroom
#         if len(re.findall('BA',title_tag))>0:
#             number = title_tag.find('BA')-1
#             bathroom.append(title_tag[number])
#         else:
#             #only one
#             bathroom.append(1)    
        
#         #neighborhoods
#         neighbor_id = 'listing-{}-neighborhoods'.format(house_id)
#         neighbor = house.find_all('div',{'id': neighbor_id})[0].text.strip()
#         neighborhoods.append(neighbor)
        
#         # address
# #         address = [address_name + ',' + neighbor]

        
#         # expert
#         expert_div = house.find_all('div',{'class':'font-size-80 overflow-clip'})
#         if len(expert_div)>0:
#             expert.append(expert_div[0].text.strip())
#         else:
#             expert.append(0)
            
#         #latitude & longitude
        
# #         for i in neighborhoods: 
# #             google_key="AIzaSyBGkYZ7kecirliN_CmzK_n4Nv5T9uH8uog"   
# #             google_url = "https://maps.googleapis.com/maps/api/geocode/json?address={}&key={}".format(i,google_key)
# #             json_return = requests.get(google_url)
# #             json_map_data = json.loads(json_return.text)
# #             for js in json_map_data['results']:
# #                 lat = js['geometry']['location']['lat']
# #                 lng = js['geometry']['location']['lng']
# #                 latitude.append(lat)
# #                 longitude.append(lng)
#         # no fee    
#         noFee = []
#         for a in Amenities:
#             if("No Fee" in a):
#                 noFee.append(1)
#             else:
#                 noFee.append(0)
# Out:
# <!DOCTYPE doctype html>
#
# <html lang="en">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="en" http-equiv="Content-Language"/>
# <title>Apartments for Rent in NYC, including No Fee | RentHop</title>
# <meta content="Newly listed NYC apartments for rent. Smooth work commute, popular bars and nightlife, nearby restaurants and grocery stores, and safety. Find your perfect home in New York, NY." name="description"/>
# <meta content="RentHop" name="author"/>
# <meta content="Copyright (c) 2009 - 2017 RentHop.com" name="Copyright"/>
# <meta content="124300320712" property="fb:page_id"/>
# <meta content="294321126236" property="fb:app_id"/>
# <meta content="https://www.renthop.com/images/renthop_icon_small.png" name="og:image"/>
# <link href="https://www.renthop.com/images/renthop_icon_small.png" rel="image_src"/>
# <meta content="Apartments for Rent in NYC, including No Fee | RentHop" name="og:title"/>
# <meta content="Newly listed NYC apartments for rent. Smooth work commute, popular bars and nightlife, nearby restaurants and grocery stores, and safety. Find your perfect home in New York, NY." name="og:description"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="@renthop" name="twitter:site"/>
# <meta content="Apartments for Rent in NYC, including No Fee | RentHop" name="twitter:title"/>
# <meta content="Newly listed NYC apartments for rent. Smooth work commute, popular bars and nightlife, nearby restaurants and grocery stores, and safety. Find your perfect home in New York, NY." name="twitter:description"/>
# <meta content="@renthop" name="twitter:creator"/>
# <meta content="https://www.renthop.com/images/renthop_icon_small.png" name="twitter:image"/>
# <meta content="renthop.com" name="twitter:domain"/>
# <link href="/nyc/apartments-for-rent" rel="canonical"/>
# <meta content="/nyc/apartments-for-rent" property="og:url"/>
# <link href="/nyc/apartments-for-rent?page=2" rel="next"/>
# <meta content="width=device-width, initial-scale=1, user-scalable=yes" name="viewport">
# <link href="/css/style_web.css?20170601" rel="stylesheet">
# <link href="/images/favicon.png" rel="icon" type="image/png"/>
# <script src="/js/jquery.js?20170601"></script>
# <script src="https://maps.googleapis.com/maps/api/js?v=3.exp&amp;libraries=places,geometry&amp;key=AIzaSyC95OBLIl2TQAfU5sc4Vwl7LFK1FzF2_as"></script>
# <script type="text/javascript"> var googletag = googletag || {}; googletag.cmd = googletag.cmd || []; (function() { var gads = document.createElement('script'); gads.async = true; gads.type = 'text/javascript'; var useSSL = 'https:' == document.location.protocol; gads.src = (useSSL ? 'https:' : 'http:') + '//www.googletagservices.com/tag/js/gpt.js'; var node = document.getElementsByTagName('script')[0]; node.parentNode.insertBefore(gads, node); })(); </script> <script type="text/javascript"> googletag.cmd.push(function() {googletag.defineSlot('/4373139/search_300x250_1', [300, 250], 'div-gpt-ad-1391216786350-0').addService(googletag.pubads()); googletag.defineSlot('/4373139/search_300x250_2', [300, 250], 'div-gpt-ad-1391216813363-0').addService(googletag.pubads()); googletag.pubads().setTargeting('location', ["new-york-city-ny"]);googletag.pubads().enableSingleRequest(); googletag.enableServices(); }); </script>
# </link></meta></head>
# <body style="margin: 0px; padding: 0px; ">
# <div id="nav-header" style="width: 100%">
# <div id="nav-header-title">
# <div class="color-bg-white shadow-3px" id="browse-selector" style="border: 1px #bbb solid; border-top: none; display: none; position: absolute; top: 55px; z-index: 102; background-color: #fff">
# <div style="z-index: 101; position: absolute; top: -6px; left: 170px; display: inline-block; width: 0; height: 0; border-left: 6px solid transparent; border-right: 6px solid transparent; border-bottom: 6px solid #ffffff;"></div>
# <div style="padding: 15px 25px 20px 25px">
# <div style="display: flex; flex-flow: row; align-items:stretch;">
# <div style="flex-basis: auto; flex-grow:1; margin-right: 35px;">
# <div class="font-size-85 bold" style="text-align: center; padding-bottom: 15px; margin-bottom: 5px; border-bottom: 1px #dddddd solid">Major areas</div>
# <div class="font-size-80 browse-links">
# <div><a href="/nyc/bronx-apartments">Bronx</a></div>
# <div><a href="/nyc/brooklyn-apartments">Brooklyn</a></div>
# <div><a href="/nyc/jersey-city-apartments">Jersey City</a></div>
# <div><a href="/nyc/manhattan-apartments">Manhattan</a></div>
# <div><a href="/nyc/queens-apartments">Queens</a></div>
# <div><a href="/nyc/staten-island-apartments">Staten Island</a></div>
# </div>
# </div>
# <div style="flex-basis: auto; flex-grow:2">
# <div class="font-size-85 bold" style="text-align: center; padding-bottom: 15px; margin-bottom: 5px; border-bottom: 1px #dddddd solid">Popular neighborhoods</div>
# <div class="font-size-80 browse-links browse-links-columns-2">
# <div><a href="/nyc/chelsea-apartments">Chelsea</a></div>
# <div><a href="/nyc/east-harlem-apartments">East Harlem</a></div>
# <div><a href="/nyc/east-village-apartments">East Village</a></div>
# <div><a href="/nyc/financial-district-apartments">Financial District</a></div>
# <div><a href="/nyc/gramercy-park-apartments">Gramercy Park</a></div>
# <div><a href="/nyc/hells-kitchen-apartments">Hell's Kitchen</a></div>
# <div><a href="/nyc/kips-bay-apartments">Kips Bay</a></div>
# <div><a href="/nyc/long-island-city-apartments">Long Island City</a></div>
# <div><a href="/nyc/midtown-east-apartments">Midtown East</a></div>
# <div><a href="/nyc/murray-hill-apartments">Murray Hill</a></div>
# <div><a href="/nyc/upper-east-side-apartments">Upper East Side</a></div>
# <div><a href="/nyc/upper-west-side-apartments">Upper West Side</a></div>
# <div><a href="/nyc/washington-heights-apartments">Washington Heights</a></div>
# <div><a href="/nyc/west-harlem-apartments">West Harlem</a></div>
# <div><a href="/nyc/west-village-apartments">West Village</a></div>
# <div><a href="/nyc/williamsburg-apartments">Williamsburg</a></div>
# </div>
# </div>
# <div style="flex-basis: auto; flex-grow:1; margin-left: 35px;">
# <div class="font-size-85 bold" style="text-align: center; padding-bottom: 15px; margin-bottom: 5px; border-bottom: 1px #dddddd solid">Popular searches</div>
# <div class="font-size-80 browse-links">
# <div><a href="/nyc/apartments-for-rent">Apartments in New York, NY</a></div>
# <div><a href="/nyc/no-fee-apartments-for-rent">No Fee Apartments for Rent</a></div>
# <div><a href="/nyc/cheap-apartments-for-rent">Cheap Apartments for Rent</a></div>
# <div><a href="/nyc/studio-apartments-for-rent">Studio Apartments for Rent</a></div>
# <div><a href="/nyc/sublet-apartments-for-rent">Sublet Apartments for Rent</a></div>
# <div><a href="/nyc/doorman-apartments-for-rent">Doorman Apartments for Rent</a></div>
# <div><a href="/nyc/elevator-apartments-for-rent">Elevator Apartments for Rent</a></div>
# <div><a href="/nyc/roommate-apartments-for-rent">Rooms for Rent</a></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div style="margin-left: auto; margin-right: auto; ">
# <div id="nav-header-div">
# <div id="options-menu-overlay" style="display: none; position: fixed; top: 0; left: 0; width: 100%; height: 100%; background-color: rgba(0, 0, 0, 0.85); z-index: 9000; text-align: left;"></div>
# <div class="large-screen" style="position: absolute; right: 0px; top: 0px; height: 20px; z-index: 1">
# <a class="nav-header-link" href="/r/listings/post" style="padding-left: 0px; padding-right: 0px; color: #fff">Post Rental</a>
# <a class="options-menu-button nav-header-link" href="/account/login" style="margin-left: 25px; padding-left: 0px; padding-right: 0px; color: #fff">Login</a>
# </div>
# <div class="small-screen" style="text-align: right; float: right; padding-top: 16px; margin-right: 10px;">
# <div style="display: inline-block;">
# <a class="bold color-fg-white font-size-90" href="/search/nyc" style="text-decoration: none;">Search</a>
# </div><div style="margin-left: 15px; display: inline-block;">
# <a class="bold color-fg-white font-size-90" href="/renter/favorites" style="text-decoration: none;">Favorites</a>
# </div><div class="options-menu-button bold color-fg-white font-size-90" style="margin-left: 15px; display: inline-block;">
# Login
# </div>
# </div>
# <div id="options-menu-login">
# <div class="bold font-size-85" style="color: #666666; text-align: center; margin-top: 20px; margin-bottom: 20px;">
# Login to RentHop
# </div>
# <div style="background-color: #ffffff;">
# <a href="/account/login" id="options-menu-login-email-link" style="display: block; border-top: 1px #ddd solid; border-bottom: 1px solid #dddddd; height: 24px; padding-top: 12px; padding-bottom: 12px; text-decoration: none;">
# <table style="height: 100%; width: 100%;">
# <tr>
# <td style="width: 60px; text-align: right;">
# <img alt="Login with Email" src="/images/mobile-email-2.png" style="width: 24px; height: 24px;"/>
# </td>
# <td class="color-fg-blue font-size-85" style="padding-left: 16px; padding-bottom: 2px;">
# Login with Email
# </td>
# </tr>
# </table>
# </a>
# <a href="#" onclick="Login.facebook_login()" style="display: block; border-bottom: 1px solid #dddddd; height: 24px; padding-top: 12px; padding-bottom: 12px; text-decoration: none">
# <table style="height: 100%; width: 100%;">
# <tr>
# <td style="width: 60px; text-align: right;">
# <img alt="Login with Facebook" src="/images/icon-facebook.png" style="width: 24px; height: 24px;"/>
# </td>
# <td class="color-fg-blue font-size-85" style="padding-left: 16px; padding-bottom: 2px;">
# Login with Facebook
# </td>
# </tr>
# </table>
# </a>
# <a href="#" onclick="Login.google_login()" style="display: block; border-bottom: 1px solid #dddddd; height: 24px; padding-top: 12px; padding-bottom: 12px; text-decoration: none;">
# <table style="height: 100%; width: 100%">
# <tr>
# <td style="width: 60px; text-align: right;">
# <img alt="Login with Google" src="/images/icon-google.png" style="width: 24px; height: 24px;"/>
# </td>
# <td class="color-fg-blue font-size-85" style="padding-left: 16px; padding-bottom: 2px;">
# Login with Google
# </td>
# </tr>
# </table>
# </a>
# </div>
# <div class="font-size-85" style="color: #666666; text-align: center; margin-top: 20px;">
# Don't have an account?
# </div>
# <div style="text-align: center; margin-top: 4px;">
# <a class="font-size-85 color-fg-blue" href="/account/register" id="options-menu-login-signup-link" style="text-decoration: none">Sign Up</a>
# </div>
# </div>
# <div id="options-menu-login-email">
# <div style="position: absolute; bottom: 20px; left: 0px; width: 240px;">
# <div class="color-fg-blue font-size-85" style="text-align: center;"><a class="color-fg-blue" href="/account/password_reset" style="text-decoration: none">Forgot Password?</a></div>
# </div>
# <div class="bold font-size-85" style="color: #666666; text-align: center; margin-top: 20px; margin-bottom: 20px;">
# Login with Email
# </div>
# <form action="/account/login_request" id="id-login-email-form" method="POST" onsubmit="return Login.login_mobile();">
# <div style="border-top: 1px solid #dddddd; border-bottom: 1px solid #dddddd;">
# <input class="font-size-85 color-bg-white" id="id-login-email-address-input" name="username" placeholder="Email" style="box-sizing: border-box; width: 100%; padding-left: 15px; padding-right: 15px; border: none; height: 42px; color: #666666;" type="text">
# </input></div>
# <div style="border-bottom: 1px solid #dddddd;">
# <input class="font-size-85 color-bg-white" id="id-login-email-password-input" name="password" placeholder="Password" style="box-sizing: border-box; padding-left: 15px; padding-right: 15px; border: none; width: 100%; height: 42px; color: #666666;" type="text">
# </input></div>
# <div class="font-size-85 color-bg-white" style="text-align: center; margin-top: 20px; margin-bottom: 16px; border: 1px solid #23a0ff; width: 160px; height: 32px; margin-left: auto; margin-right: auto;">
# <button id="id-login-button-login" style="background: none; border: none;">
# <div class="bold color-fg-blue" style="width: 160px; height: 32px; display: table-cell; vertical-align: middle;">
# Login
# </div>
# </button>
# </div>
# <div class="color-fg-red font-size-85" id="login-status-box" style="text-align: center; display: none;"></div>
# </form>
# </div>
# <div id="options-menu-login-signup">
# <div class="bold font-size-85" style="color: #666666; text-align: center; margin-top: 20px; margin-bottom: 20px;">
# Sign Up for RentHop
# </div>
# <form action="/account/register_request" id="id-login-signup-form" method="post" onsubmit="return Login.register_mobile()">
# <div style="border-top: 1px solid #dddddd; border-bottom: 1px solid #dddddd;">
# <input class="font-size-85 color-bg-white" id="id-login-signup-address-input" name="username" placeholder="Email" style="box-sizing: border-box; padding-left: 15px; padding-right: 15px; border: none; width: 100%; height: 42px; color: #666666;" type="text">
# </input></div>
# <div style="border-bottom: 1px solid #dddddd;">
# <input class="font-size-85 color-bg-white" id="id-login-signup-password-input" name="pass1" placeholder="Password" style="box-sizing: border-box; padding-left: 15px; padding-right: 15px; border: none; width: 100%; height: 42px; color: #666666;" type="text">
# </input></div>
# <div style="padding-left: 15px; padding-right: 15px; margin-top: 15px;">
# <table>
# <tr>
# <td class="font-size-85" style="color: #666666; width: 70px;">
# I am a:
# </td>
# <td class="" style="">
# <select class="font-size-80 corner-none" id="id-login-select-type" name="purpose" style="background: #ffffff; border: 1px solid #dddddd; width: 140px; padding: 10px;">
# <option value="renter">Renter</option>
# <option value="agent">Agent</option>
# <option value="landlord">Owner / Manager</option>
# </select>
# </td>
# </tr>
# </table>
# </div>
# <div style="padding-left: 15px; padding-right: 15px; margin-top: 10px;">
# <table>
# <tr>
# <td class="font-size-85" style="color: #666666; width: 70px;">
# Location:
# </td>
# <td class="" style="">
# <select class="font-size-80 corner-none" id="id-login-select-location" name="region" style="background: #ffffff; border: 1px solid #dddddd; width: 140px; padding: 10px;">
# <option value="nyc">NYC Area</option>
# <option value="nation">National (Non-NYC)</option>
# </select>
# </td>
# </tr>
# </table>
# </div>
# <div class="font-size-85 color-bg-white" style="text-align: center; margin-top: 20px; margin-bottom: 16px; border: 1px solid #23a0ff; width: 160px; height: 32px; margin-left: auto; margin-right: auto;">
# <button id="id-login-button-signup-new" style="background: none; border: none;">
# <div class="bold color-fg-blue" style="width: 160px; height: 32px; display: table-cell; vertical-align: middle;">
# Sign Up
# </div>
# </button>
# </div>
# <div class="color-fg-red font-size-85" id="register-status-box" style="text-align: center; display: none; margin-bottom: 10px;"></div>
# </form>
# </div>
# <script>
#
#   function close_reset_overlays() {
#     $("#options-menu-overlay").hide();
#     $("#options-menu-login").hide();
#     $("#options-menu-login-email").hide();
#     $("#options-menu-login-signup").hide();
#     $("#login-status-box").hide();
#     $("#register-status-box").hide();
#   }
#
#   $('#id-login-email-password-input').focus(
#     function(){
#       var pass = $('<input id="id-login-email-password-input" style="box-sizing: border-box; padding-left: 15px; padding-right: 15px; border: none; width: 100%; height: 42px; color: #666666;" class="font-size-85 color-bg-white" type="password" name="password" placeholder="Password">');
#       $(this).replaceWith(pass);
#       pass.focus();
#     }
#   );
#
#   $('#id-login-signup-password-input').focus(
#     function(){
#       var pass = $('<input id="id-login-signup-password-input" style="box-sizing: border-box; padding-left: 15px; padding-right: 15px; border: none; width: 100%; height: 42px; color: #666666;" class="font-size-85 color-bg-white" type="password" name="pass1" placeholder="Password">');
#       $(this).replaceWith(pass);
#       pass.focus();
#       }
#     );
#
#   $("#options-menu-login").click(function(e) {
#     e.stopPropagation();
#   });
#
#   $("#options-menu-login-email").click(function(e) {
#     e.stopPropagation();
#   });
#
#   $("#options-menu-login-signup").click(function(e) {
#     e.stopPropagation();
#   });
#
#   $(".options-menu-button").click(function(e) {
#     $("#options-menu-overlay").show();
#     $("#options-menu-login").show();
#     return false;
#   });
#
#   $("#options-menu-overlay, body").click(function() {
#     close_reset_overlays();
#   });
#
#   $("#options-menu-login-email-link").click(function() {
#     $("#options-menu-login").hide();
#     $("#options-menu-login-email").show();
#     return false;
#   });
#
#   $("#options-menu-login-signup-link").click(function() {
#     $("#options-menu-login").hide();
#     $("#options-menu-login-signup").show();
#     return false;
#   });
#
#
# </script>
# <div id="nav-header-mascot" style="left: 0px; top: 6px; position: absolute; z-index: 100;">
# <div style="width: 32px; height: 32px; border-radius: 4px; background-color: #333f47; position: absolute; top: 5px; left: -50px; background-image: url('/images/wally-mini.png'); background-position: 125% 0%;"></div>
# </div>
# <div id="nav-header-image" style="position: relative; display: inline-block;">
# <a href="/" title="Apartments for Rent | RentHop.com">
# <img alt="Apartments for Rent | RentHop.com" class="small-screen" src="/images/logo-mobile-white.png" style="height: 21px; width: 67px"/>
# <img alt="Apartments for Rent | RentHop.com" class="large-screen" src="/images/logo-white.png" style="height: 24px; width: 73px;"/>
# </a>
# </div>
# <div class="large-screen" style="top: 0px; position: absolute; left: 120px;">
# <div style="margin-right: 15px; margin-top: 18px; position: relative; display: inline-block; height: 20px; width: 0px; border-right: 1px solid #555555;"></div>
# <a class="nav-header-link" href="/search/nyc" id="browse-selector-link" style="cursor: pointer; color: #fff">Browse</a>
# <a class="nav-header-link" href="/blog" style="color: #fff">Resources</a>
# <a class="nav-header-link" href="/renter/favorites" style="color: #fff">Favorites</a>
# <a class="nav-header-link" href="/nyc/roommate-apartments-for-rent" style="color: #fff">Find Roommates</a>
# </div>
# <script>
#
#           $('#browse-selector-link,#browse-selector').hover( function() { $('#browse-selector').css('display', 'block'); }, function() { $('#browse-selector').css('display', 'none'); });
#
#         </script>
# </div>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#
#
#   $(function() {
#     $("#promo-app-banner-close").click(function(e) {
#       $("#promo-app-banner").css("display", "none");
#       Promo.promo_app_hide();
#       e.stopPropagation();
#     });
#   });
#
#
# </script>
# <style type="text/css">#list-mode-highlight{display:block!important;}</style>
# <input id="metro_alias" name="metro_alias" type="hidden" value="nyc">
# <form action="/search/nyc" id="search_form" method="get">
# <div id="sticky-search-bar">
# <div class="col-1" style="margin-left: auto; margin-right: auto;">
# <div class="color-bg-white" style="width: 60px; display: inline-block; position: relative; vertical-align: top;">
# <div id="search-type-select">
# <div id="search-type-neighborhood">
# <img alt="Neighborhood Search" src="/images/search-neighborhoods.png" style="position: absolute; left: 9px; top: 7px; height: 20px; width: 20px;"/>
# <div style="position: absolute; right: 8px; top: 9px; opacity: 0.75;">
# <img alt="Down Arrow" src="/images/combo-dropdown-blue.png"/>
# </div>
# </div>
# <div id="search-type-college">
# <img alt="College Search" src="/images/search-colleges.png" style="position: absolute; left: 9px; top: 7px; height: 20px; width: 20px;"/>
# <div style="position: absolute; right: 8px; top: 9px; opacity: 0.75;">
# <img alt="Down Arrow" src="/images/combo-dropdown-purple.png"/>
# </div>
# </div>
# <div id="search-type-location">
# <img alt="Location Search" src="/images/search-locations.png" style="position: absolute; left: 12px; top: 6px; height: 22px; width: 14px;"/>
# <div style="position: absolute; right: 8px; top: 9px; opacity: 0.75;">
# <img alt="Down Arrow" src="/images/combo-dropdown-green.png"/>
# </div>
# </div>
# </div>
# <div class="color-bg-white shadow-2px" id="search-type-selector" style="cursor: default; background-color: #ffffff; width: 259px; z-index: 100; border: 1px solid #999999; border-top: none; position: absolute; top: 45px; left: 0px; display: none;">
# <div style="z-index: 101; position: absolute; top: -16px; left: 22px;"><img alt="Caret" src="/images/menu-caret-2.png"/></div>
# <div class="font-size-85" id="listings-search-neighborhood-button" style="cursor: pointer; padding: 14px 0px 12px 10px; border-bottom: 1px solid #eeeeee;">Search Neighborhoods</div>
# <div class="font-size-85" id="listings-search-college-button" style="cursor: pointer; padding: 12px 0px 12px 10px; border-bottom: 1px solid #eeeeee;">Search Near Colleges</div>
# <div class="font-size-85" id="listings-search-location-button" style="cursor: pointer; padding: 12px 0px 14px 10px; border-bottom: 1px solid #eeeeee;">Search Anywhere</div>
# </div>
# </div><div class="color-fg-light-gray" style="position: relative; display: inline-block; vertical-align: top">
# <div class="font-size-90 color-bg-white neighborhood-select-border" id="search-neighborhood-select" style="position: relative; cursor: pointer; width: 180px; height: 34px; padding-left: 10px; padding-right: 10px;">
# <div style="position: absolute; right: 8px; top: 9px;"><img alt="Down Arrow" src="/images/combo-dropdown-gray.png"/></div>
# <div style="width: 180px; display: table-cell; vertical-align: middle; height: 34px;">
# <div style="width: 160px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;">
# <div id="neighborhood-text" style="height: 100%; display: none;"></div>
# <div id="college-text" style="display: none;">Select College</div>
# <div id="location-text" style="display: none;">Choose Location</div>
# </div>
# </div>
# </div>
# <div class="shadow-2px" id="universal-selector" style="z-index: 100; position: absolute; top: 45px; left: -60px; display: none; border: 1px solid #bbbbbb; border-top: none;">
# <div class="selector-menu-carat" style="z-index: 101; position: absolute; top: -16px; left: 145px;"><img alt="Caret" src="/images/menu-caret-2.png"/></div>
# <style></style>
# <div class="color-bg-white" id="neighborhood-selector" style="">
# <div id="neighborhood-tabs-close" style="width: 100%; position: fixed; bottom: 0px; height: 65px; border-top: 10px solid #dddddd; background-color: #f6f6f6;">
# <div class="bold" id="map-selector-search-button" style="float: right; cursor: pointer; font-size: 16px; background-color: #0091ff; color: #ffffff; border: 1px solid #ffffff; margin: 12px 15px 0px 0px; width: 120px; height: 38px; line-height: 38px; text-align: center;">
# Search
# </div>
# <div class="bold" id="neighborhood-tabs-close-button" style="cursor: pointer; font-size: 16px; background-color: #888888; color: #ffffff; border: 1px solid #ffffff; margin: 12px 0px 0px 15px; width: 120px; height: 38px; line-height: 38px; text-align: center;">
# Close
# </div>
# </div>
# <div id="neighborhood-selector-main-tab">
# <table style="width: 100%;">
# <tr>
# <td id="neighborhood-selector-map">
# <div style="z-index: 101; position: absolute; top: 0px; left: 0px; width: 100%;">
# <div id="neighborhood-selector-legend" style="display: none; text-align: center;"></div>
# </div>
# <div id="neighborhood-selector-subtext" style="text-align: center;">
# Drag &amp; Zoom Enabled
# </div>
# <div id="neighborhood-selector-map-canvas"></div>
# </td>
# <td id="neighborhood-selector-tabs" style="vertical-align: top;">
# <div id="neighborhood-tabs-title">
# Neighborhoods
# </div>
# <div class="checkbox-label-selector" id="tabs">
# <div class="tab-link-single" style="cursor: pointer;">
# <div class="tab-link tab-link-single-no-border" data-key="1" id="tab-1-link">
# <div class="tabs-triangle-down" data-key="1"></div>
# Manhattan
# (<span class="tab-link-count" data-key="1" id="tab-1-link-count" style="color: inherit;">0</span>)
# </div>
# </div>
# <div class="tab-single-hide tab-single" id="tab-1">
# <input class="data-selector-county" data-local_id="1" style="display: none" type="checkbox" value="Manhattan"/>
# <div class="tab-options font-size-80" id="tab-1-options" style="margin-top: 0px; margin-bottom: 10px;" tab_num="1">
# <a class="color-fg-blue county-select" href="#">Select All</a> <span style="color: #cfcfcf"> | </span> <a class="color-fg-blue county-clear" href="#">Clear All</a>
# </div>
# <div class="neighborhood-columns-container" id="neighborhood-column-1" style="display: block;" tab_num="1">
# <div class="neighborhood-group">
# <div class="neighborhood-group-item">
# <input class="cb data-selector-macro" data-local_id="7" id="selector-nh-7" type="checkbox" value="Downtown Manhattan"/>
# <label class="search-label" for="selector-nh-7"><span class="search-cb cb"></span><span>Downtown Manhattan</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="51" id="selector-nh-51" type="checkbox" value="Battery Park City"/>
# <label class="search-label" for="selector-nh-51"><span class="search-cb cb"></span><span>Battery Park City</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="69" id="selector-nh-69" type="checkbox" value="Bowery"/>
# <label class="search-label" for="selector-nh-69"><span class="search-cb cb"></span><span>Bowery</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="102" id="selector-nh-102" type="checkbox" value="Chinatown"/>
# <label class="search-label" for="selector-nh-102"><span class="search-cb cb"></span><span>Chinatown</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="92" id="selector-nh-92" type="checkbox" value="Civic Center"/>
# <label class="search-label" for="selector-nh-92"><span class="search-cb cb"></span><span>Civic Center</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="35" id="selector-nh-35" type="checkbox" value="East Village"/>
# <label class="search-label" for="selector-nh-35"><span class="search-cb cb"></span><span>East Village</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="31" id="selector-nh-31" type="checkbox" value="Financial District"/>
# <label class="search-label" for="selector-nh-31"><span class="search-cb cb"></span><span>Financial District</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="42" id="selector-nh-42" type="checkbox" value="Greenwich Village"/>
# <label class="search-label" for="selector-nh-42"><span class="search-cb cb"></span><span>Greenwich Village</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="88" id="selector-nh-88" type="checkbox" value="Little Italy"/>
# <label class="search-label" for="selector-nh-88"><span class="search-cb cb"></span><span>Little Italy</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="59" id="selector-nh-59" type="checkbox" value="Lower East Side"/>
# <label class="search-label" for="selector-nh-59"><span class="search-cb cb"></span><span>Lower East Side</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="80" id="selector-nh-80" type="checkbox" value="NoHo"/>
# <label class="search-label" for="selector-nh-80"><span class="search-cb cb"></span><span>NoHo</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="71" id="selector-nh-71" type="checkbox" value="NoLita"/>
# <label class="search-label" for="selector-nh-71"><span class="search-cb cb"></span><span>NoLita</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="58" id="selector-nh-58" type="checkbox" value="SoHo"/>
# <label class="search-label" for="selector-nh-58"><span class="search-cb cb"></span><span>SoHo</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="44" id="selector-nh-44" type="checkbox" value="Tribeca"/>
# <label class="search-label" for="selector-nh-44"><span class="search-cb cb"></span><span>Tribeca</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="127" id="selector-nh-127" type="checkbox" value="Two Bridges"/>
# <label class="search-label" for="selector-nh-127"><span class="search-cb cb"></span><span>Two Bridges</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="39" id="selector-nh-39" type="checkbox" value="West Village"/>
# <label class="search-label" for="selector-nh-39"><span class="search-cb cb"></span><span>West Village</span></label>
# </div>
# </div>
# <div class="neighborhood-group">
# <div class="neighborhood-group-item">
# <input class="cb data-selector-macro" data-local_id="8" id="selector-nh-8" type="checkbox" value="Midtown Manhattan"/>
# <label class="search-label" for="selector-nh-8"><span class="search-cb cb"></span><span>Midtown Manhattan</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="33" id="selector-nh-33" type="checkbox" value="Chelsea"/>
# <label class="search-label" for="selector-nh-33"><span class="search-cb cb"></span><span>Chelsea</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="57" id="selector-nh-57" type="checkbox" value="Flatiron District"/>
# <label class="search-label" for="selector-nh-57"><span class="search-cb cb"></span><span>Flatiron District</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="54" id="selector-nh-54" type="checkbox" value="Garment District"/>
# <label class="search-label" for="selector-nh-54"><span class="search-cb cb"></span><span>Garment District</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="47" id="selector-nh-47" type="checkbox" value="Gramercy Park"/>
# <label class="search-label" for="selector-nh-47"><span class="search-cb cb"></span><span>Gramercy Park</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="32" id="selector-nh-32" type="checkbox" value="Hell's Kitchen"/>
# <label class="search-label" for="selector-nh-32"><span class="search-cb cb"></span><span>Hell's Kitchen</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="37" id="selector-nh-37" type="checkbox" value="Kips Bay"/>
# <label class="search-label" for="selector-nh-37"><span class="search-cb cb"></span><span>Kips Bay</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="87" id="selector-nh-87" type="checkbox" value="Koreatown"/>
# <label class="search-label" for="selector-nh-87"><span class="search-cb cb"></span><span>Koreatown</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="34" id="selector-nh-34" type="checkbox" value="Midtown East"/>
# <label class="search-label" for="selector-nh-34"><span class="search-cb cb"></span><span>Midtown East</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="36" id="selector-nh-36" type="checkbox" value="Murray Hill"/>
# <label class="search-label" for="selector-nh-36"><span class="search-cb cb"></span><span>Murray Hill</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="75" id="selector-nh-75" type="checkbox" value="NoMad"/>
# <label class="search-label" for="selector-nh-75"><span class="search-cb cb"></span><span>NoMad</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="65" id="selector-nh-65" type="checkbox" value="Stuyvesant Town - Peter Cooper Village"/>
# <label class="search-label" for="selector-nh-65"><span class="search-cb cb"></span><span>Stuyvesant Town - Peter Cooper Village</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="43" id="selector-nh-43" type="checkbox" value="Theater District"/>
# <label class="search-label" for="selector-nh-43"><span class="search-cb cb"></span><span>Theater District</span></label>
# </div>
# </div>
# <div class="neighborhood-group">
# <div class="neighborhood-group-item">
# <input class="cb data-selector-macro" data-local_id="9" id="selector-nh-9" type="checkbox" value="Upper Manhattan"/>
# <label class="search-label" for="selector-nh-9"><span class="search-cb cb"></span><span>Upper Manhattan</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="48" id="selector-nh-48" type="checkbox" value="Central Harlem"/>
# <label class="search-label" for="selector-nh-48"><span class="search-cb cb"></span><span>Central Harlem</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="68" id="selector-nh-68" type="checkbox" value="Central Park"/>
# <label class="search-label" for="selector-nh-68"><span class="search-cb cb"></span><span>Central Park</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="49" id="selector-nh-49" type="checkbox" value="East Harlem"/>
# <label class="search-label" for="selector-nh-49"><span class="search-cb cb"></span><span>East Harlem</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="70" id="selector-nh-70" type="checkbox" value="Inwood"/>
# <label class="search-label" for="selector-nh-70"><span class="search-cb cb"></span><span>Inwood</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="29" id="selector-nh-29" type="checkbox" value="Upper East Side"/>
# <label class="search-label" for="selector-nh-29"><span class="search-cb cb"></span><span>Upper East Side</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="30" id="selector-nh-30" type="checkbox" value="Upper West Side"/>
# <label class="search-label" for="selector-nh-30"><span class="search-cb cb"></span><span>Upper West Side</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="46" id="selector-nh-46" type="checkbox" value="Washington Heights"/>
# <label class="search-label" for="selector-nh-46"><span class="search-cb cb"></span><span>Washington Heights</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="53" id="selector-nh-53" type="checkbox" value="West Harlem"/>
# <label class="search-label" for="selector-nh-53"><span class="search-cb cb"></span><span>West Harlem</span></label>
# </div>
# </div>
# <div class="neighborhood-group">
# <div class="neighborhood-group-item">
# <input class="cb data-selector-macro" data-local_id="10000" id="selector-nh-10000" type="checkbox" value="Other"/>
# <label class="search-label" for="selector-nh-10000"><span class="search-cb cb"></span><span>Other</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="193" id="selector-nh-193" type="checkbox" value="Randalls-Wards Island"/>
# <label class="search-label" for="selector-nh-193"><span class="search-cb cb"></span><span>Randalls-Wards Island</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="97" id="selector-nh-97" type="checkbox" value="Roosevelt Island"/>
# <label class="search-label" for="selector-nh-97"><span class="search-cb cb"></span><span>Roosevelt Island</span></label>
# </div>
# </div>
# </div>
# </div>
# <div class="tab-link-single" style="cursor: pointer;">
# <div class="tab-link tab-link-single-border" data-key="2" id="tab-2-link">
# <div class="tabs-triangle-down" data-key="2"></div>
# Brooklyn
# (<span class="tab-link-count" data-key="2" id="tab-2-link-count" style="color: inherit;">0</span>)
# </div>
# </div>
# <div class="tab-single-hide tab-single" id="tab-2">
# <input class="data-selector-county" data-local_id="2" style="display: none" type="checkbox" value="Brooklyn"/>
# <div class="tab-options font-size-80" id="tab-2-options" style="margin-top: 0px; margin-bottom: 10px;" tab_num="2">
# <a class="color-fg-blue county-select" href="#">Select All</a> <span style="color: #cfcfcf"> | </span> <a class="color-fg-blue county-clear" href="#">Clear All</a>
# </div>
# <div class="neighborhood-columns-container" id="neighborhood-column-2" style="display: block;" tab_num="2">
# <div class="neighborhood-group">
# <div class="neighborhood-group-item">
# <input class="cb data-selector-macro" data-local_id="10" id="selector-nh-10" type="checkbox" value="Northern Brooklyn"/>
# <label class="search-label" for="selector-nh-10"><span class="search-cb cb"></span><span>Northern Brooklyn</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="38" id="selector-nh-38" type="checkbox" value="Bedford-Stuyvesant"/>
# <label class="search-label" for="selector-nh-38"><span class="search-cb cb"></span><span>Bedford-Stuyvesant</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="40" id="selector-nh-40" type="checkbox" value="Bushwick"/>
# <label class="search-label" for="selector-nh-40"><span class="search-cb cb"></span><span>Bushwick</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="77" id="selector-nh-77" type="checkbox" value="Greenpoint"/>
# <label class="search-label" for="selector-nh-77"><span class="search-cb cb"></span><span>Greenpoint</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="41" id="selector-nh-41" type="checkbox" value="Williamsburg"/>
# <label class="search-label" for="selector-nh-41"><span class="search-cb cb"></span><span>Williamsburg</span></label>
# </div>
# </div>
# <div class="neighborhood-group">
# <div class="neighborhood-group-item">
# <input class="cb data-selector-macro" data-local_id="12" id="selector-nh-12" type="checkbox" value="South Brooklyn"/>
# <label class="search-label" for="selector-nh-12"><span class="search-cb cb"></span><span>South Brooklyn</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="72" id="selector-nh-72" type="checkbox" value="Boerum Hill"/>
# <label class="search-label" for="selector-nh-72"><span class="search-cb cb"></span><span>Boerum Hill</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="86" id="selector-nh-86" type="checkbox" value="Carroll Gardens"/>
# <label class="search-label" for="selector-nh-86"><span class="search-cb cb"></span><span>Carroll Gardens</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="99" id="selector-nh-99" type="checkbox" value="Cobble Hill"/>
# <label class="search-label" for="selector-nh-99"><span class="search-cb cb"></span><span>Cobble Hill</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="85" id="selector-nh-85" type="checkbox" value="Gowanus"/>
# <label class="search-label" for="selector-nh-85"><span class="search-cb cb"></span><span>Gowanus</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="73" id="selector-nh-73" type="checkbox" value="Greenwood Heights"/>
# <label class="search-label" for="selector-nh-73"><span class="search-cb cb"></span><span>Greenwood Heights</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="50" id="selector-nh-50" type="checkbox" value="Park Slope"/>
# <label class="search-label" for="selector-nh-50"><span class="search-cb cb"></span><span>Park Slope</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="120" id="selector-nh-120" type="checkbox" value="Prospect Park"/>
# <label class="search-label" for="selector-nh-120"><span class="search-cb cb"></span><span>Prospect Park</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="111" id="selector-nh-111" type="checkbox" value="Red Hook"/>
# <label class="search-label" for="selector-nh-111"><span class="search-cb cb"></span><span>Red Hook</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="84" id="selector-nh-84" type="checkbox" value="Sunset Park"/>
# <label class="search-label" for="selector-nh-84"><span class="search-cb cb"></span><span>Sunset Park</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="98" id="selector-nh-98" type="checkbox" value="Windsor Terrace"/>
# <label class="search-label" for="selector-nh-98"><span class="search-cb cb"></span><span>Windsor Terrace</span></label>
# </div>
# </div>
# <div class="neighborhood-group">
# <div class="neighborhood-group-item">
# <input class="cb data-selector-macro" data-local_id="13" id="selector-nh-13" type="checkbox" value="Central Brooklyn"/>
# <label class="search-label" for="selector-nh-13"><span class="search-cb cb"></span><span>Central Brooklyn</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="52" id="selector-nh-52" type="checkbox" value="Crown Heights"/>
# <label class="search-label" for="selector-nh-52"><span class="search-cb cb"></span><span>Crown Heights</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="79" id="selector-nh-79" type="checkbox" value="East Flatbush"/>
# <label class="search-label" for="selector-nh-79"><span class="search-cb cb"></span><span>East Flatbush</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="55" id="selector-nh-55" type="checkbox" value="Flatbush"/>
# <label class="search-label" for="selector-nh-55"><span class="search-cb cb"></span><span>Flatbush</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="89" id="selector-nh-89" type="checkbox" value="Kensington"/>
# <label class="search-label" for="selector-nh-89"><span class="search-cb cb"></span><span>Kensington</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="100" id="selector-nh-100" type="checkbox" value="Midwood"/>
# <label class="search-label" for="selector-nh-100"><span class="search-cb cb"></span><span>Midwood</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="82" id="selector-nh-82" type="checkbox" value="Ocean Hill"/>
# <label class="search-label" for="selector-nh-82"><span class="search-cb cb"></span><span>Ocean Hill</span></label>
# </div>
# </div>
# <div class="neighborhood-group">
# <div class="neighborhood-group-item">
# <input class="cb data-selector-macro" data-local_id="14" id="selector-nh-14" type="checkbox" value="Northwestern Brooklyn"/>
# <label class="search-label" for="selector-nh-14"><span class="search-cb cb"></span><span>Northwestern Brooklyn</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="60" id="selector-nh-60" type="checkbox" value="Brooklyn Heights"/>
# <label class="search-label" for="selector-nh-60"><span class="search-cb cb"></span><span>Brooklyn Heights</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="130" id="selector-nh-130" type="checkbox" value="Brooklyn Navy Yard"/>
# <label class="search-label" for="selector-nh-130"><span class="search-cb cb"></span><span>Brooklyn Navy Yard</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="61" id="selector-nh-61" type="checkbox" value="Clinton Hill"/>
# <label class="search-label" for="selector-nh-61"><span class="search-cb cb"></span><span>Clinton Hill</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="105" id="selector-nh-105" type="checkbox" value="DUMBO"/>
# <label class="search-label" for="selector-nh-105"><span class="search-cb cb"></span><span>DUMBO</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="63" id="selector-nh-63" type="checkbox" value="Downtown Brooklyn"/>
# <label class="search-label" for="selector-nh-63"><span class="search-cb cb"></span><span>Downtown Brooklyn</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="74" id="selector-nh-74" type="checkbox" value="Fort Greene"/>
# <label class="search-label" for="selector-nh-74"><span class="search-cb cb"></span><span>Fort Greene</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="78" id="selector-nh-78" type="checkbox" value="Prospect Heights"/>
# <label class="search-label" for="selector-nh-78"><span class="search-cb cb"></span><span>Prospect Heights</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="117" id="selector-nh-117" type="checkbox" value="Vinegar Hill"/>
# <label class="search-label" for="selector-nh-117"><span class="search-cb cb"></span><span>Vinegar Hill</span></label>
# </div>
# </div>
# <div class="neighborhood-group">
# <div class="neighborhood-group-item">
# <input class="cb data-selector-macro" data-local_id="15" id="selector-nh-15" type="checkbox" value="Southwestern Brooklyn"/>
# <label class="search-label" for="selector-nh-15"><span class="search-cb cb"></span><span>Southwestern Brooklyn</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="129" id="selector-nh-129" type="checkbox" value="Bath Beach"/>
# <label class="search-label" for="selector-nh-129"><span class="search-cb cb"></span><span>Bath Beach</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="62" id="selector-nh-62" type="checkbox" value="Bay Ridge"/>
# <label class="search-label" for="selector-nh-62"><span class="search-cb cb"></span><span>Bay Ridge</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="109" id="selector-nh-109" type="checkbox" value="Bensonhurst"/>
# <label class="search-label" for="selector-nh-109"><span class="search-cb cb"></span><span>Bensonhurst</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="104" id="selector-nh-104" type="checkbox" value="Borough Park"/>
# <label class="search-label" for="selector-nh-104"><span class="search-cb cb"></span><span>Borough Park</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="115" id="selector-nh-115" type="checkbox" value="Dyker Heights"/>
# <label class="search-label" for="selector-nh-115"><span class="search-cb cb"></span><span>Dyker Heights</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="122" id="selector-nh-122" type="checkbox" value="Mapleton"/>
# <label class="search-label" for="selector-nh-122"><span class="search-cb cb"></span><span>Mapleton</span></label>
# </div>
# </div>
# <div class="neighborhood-group">
# <div class="neighborhood-group-item">
# <input class="cb data-selector-macro" data-local_id="20" id="selector-nh-20" type="checkbox" value="Southern Brooklyn"/>
# <label class="search-label" for="selector-nh-20"><span class="search-cb cb"></span><span>Southern Brooklyn</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="134" id="selector-nh-134" type="checkbox" value="Brighton Beach"/>
# <label class="search-label" for="selector-nh-134"><span class="search-cb cb"></span><span>Brighton Beach</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="154" id="selector-nh-154" type="checkbox" value="Coney Island"/>
# <label class="search-label" for="selector-nh-154"><span class="search-cb cb"></span><span>Coney Island</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="108" id="selector-nh-108" type="checkbox" value="Gravesend"/>
# <label class="search-label" for="selector-nh-108"><span class="search-cb cb"></span><span>Gravesend</span></label>
# </div>
# <div class="neighborhood-single-item">
# <input class="cb" data-local_id="94" id="selector-nh-94" type="checkbox" value="Sheepshead Bay"/>
# <label class="search-label" for="selector-nh-94"><span class="search-cb cb"></span><span>Sheepshead Bay</span></label>
# </div>
# </div>
# <div class="neighborhood-group">
# <div class="neighborhood-group-item">
# ...
# <div style="padding-top: 5px;"><a class="font-size-85" href="/nyc/little-italy-apartments" style="text-decoration: none;">Little Italy</a></div>
# <div style="padding-top: 5px;"><a class="font-size-85" href="/nyc/chinatown-apartments" style="text-decoration: none;">Chinatown</a></div>
# <div style="padding-top: 5px;"><a class="font-size-85" href="/nyc/two-bridges-apartments" style="text-decoration: none;">Two Bridges</a></div>
# <div style="padding-top: 5px;"><a class="font-size-85" href="/nyc/soho-apartments" style="text-decoration: none;">SoHo</a></div>
# <div style="padding-top: 5px;"><a class="font-size-85" href="/nyc/downtown-manhattan-apartments" style="text-decoration: none;">Downtown Manhattan</a></div>
# <div style="padding-top: 5px;"><a class="font-size-85" href="/nyc/nolita-apartments" style="text-decoration: none;">NoLita</a></div>
# <div style="padding-top: 5px;"><a class="font-size-85" href="/nyc/hudson-square-apartments" style="text-decoration: none;">Hudson Square</a></div>
# <div style="padding-top: 5px;"><a class="font-size-85" href="/nyc/cooperative-village-apartments" style="text-decoration: none;">Cooperative Village</a></div>
# <div style="padding-top: 5px;"><a class="font-size-85" href="/nyc/bowery-apartments" style="text-decoration: none;">Bowery</a></div>
# <div style="padding-top: 5px;"><a class="font-size-85" href="/nyc/dumbo-apartments" style="text-decoration: none;">DUMBO</a></div>
# <div style="padding-top: 5px;"><a class="font-size-85" href="/nyc/noho-apartments" style="text-decoration: none;">NoHo</a></div>
# <div style="padding-top: 5px;"><a class="font-size-85" href="/nyc/brooklyn-heights-apartments" style="text-decoration: none;">Brooklyn Heights</a></div>
# <div style="padding-top: 5px;"><a class="font-size-85" href="/nyc/lower-east-side-apartments" style="text-decoration: none;">Lower East Side</a></div>
# <div style="padding-top: 5px;"><a class="font-size-85" href="/nyc/vinegar-hill-apartments" style="text-decoration: none;">Vinegar Hill</a></div>
# <div style="padding-top: 5px;"><a class="font-size-85" href="/nyc/greenwich-village-apartments" style="text-decoration: none;">Greenwich Village</a></div>
# <div style="padding-top: 5px;"><a class="font-size-85" href="/nyc/colgate-center-apartments" style="text-decoration: none;">Colgate Center</a></div>
# </div>
# </div>
# </div>
# </div>
# <div id="contact-listing-overlay" style="display: none; position: fixed; top: 0; left: 0; width: 100%; height: 100%; background-color: rgba(0, 0, 0, 0.65); z-index: 90000;">
# <div id="contact-listing" style="display: none; z-index: 90001; position: fixed; top: 50%; left: 50%; width: 420px; height: 500px; margin-left: -210px; margin-top: -250px; background-color: #f6f6f6; color: #ff0000; border: 1px solid #bbbbbb;">
# <div style="margin-left: 40px; margin-right: 40px; padding-top: 40px;">
# <table style="width: 100%;">
# <tr>
# <td style="vertical-align: top; width: 1px;">
# <img alt="" id="listing-img" src="" style="border: 1px solid #bbbbbb; height: 80px; width: 100px; object-fit: cover"/>
# </td>
# <td style="vertical-align: top; padding-left: 15px; max-width: 1px; overflow: hidden; text-overflow: ellipsis; white-space: nowrap;">
# <div class="bold font-size-100" id="listing-title" style="margin-top: -3px;">
# </div>
# <div class="font-size-80" id="listing-neighborhoods" style="">
# </div>
# <div style="margin-top: 10px;">
# <table>
# <tr>
# <td style="padding-right: 20px; vertical-align: bottom;">
# <div class="bold color-fg-green" id="listing-price" style="font-size: 1.10em;">
# </div>
# <div class="font-size-80" style="color: #666666;">
# Per Month
# </div>
# </td>
# <td style="padding-left: 20px; border-left: 1px solid #dddddd; vertical-align: bottom;">
# <div class="color-fg-blue bold" id="listing-hopscore" style="font-size: 1.10em;">
# </div>
# <div class="font-size-80" style="color: #666666;">
# HopScore
# </div>
# </td>
# </tr>
# </table>
# </div>
# </td>
# </tr>
# </table>
# </div>
# <div id="id-contact-form-wrapper" style="margin-left: 40px; margin-right: 40px; margin-top: 25px;">
# <form id="id-contact-form">
# <input id="use_region" name="use_region" type="hidden" value="">
# <input id="contact_listing_id" name="contact_listing_id" type="hidden" value="">
# <table style="width: 100%;">
# <tr>
# <td style="border-left: 1px solid #bbbbbb; border-right: 1px solid #bbbbbb; border-top: 1px solid #bbbbbb; border-bottom: none; background-color: #ffffff;">
# <input class="font-size-90 color-bg-white" id="renter_name" name="renter_name" placeholder="Name" style="border: none; height: 42px; width: 318px; padding: 0px 10px 0px 10px;" type="text" value=""/>
# </td>
# </tr>
# <tr>
# <td style="border: 1px solid #bbbbbb; border-top: 1px solid #dddddd; border-bottom: none; background-color: #ffffff;">
# <input class="font-size-90 color-bg-white" id="renter_phone" name="renter_phone" placeholder="Phone Number" style="border: none; height: 42px; width: 318px; padding: 0px 10px 0px 10px;" type="text" value=""/>
# </td>
# </tr>
# <tr>
# <td style="border: 1px solid #bbbbbb; border-top: 1px solid #dddddd; border-bottom: none; background-color: #ffffff;">
# <input class="font-size-90 color-bg-white" id="renter_email" name="renter_email" placeholder="Email" style="border: none; height: 42px; width: 318px; padding: 0px 10px 0px 10px;" type="text" value=""/>
# </td>
# </tr>
# <tr>
# <td style="background-color: #ffffff; border: 1px solid #bbbbbb; border-top: 1px solid #dddddd; background-color: #ffffff;">
# <textarea class="font-size-90" id="renter_comments" name="renter_comments" style="padding: 10px; resize: none; width: 318px; height: 60px; border: none;">Hi, I'm interested in this apartment. Is it still available for a showing?</textarea>
# </td>
# </tr>
# </table>
# <div style="margin-left: auto; margin-right: auto; width: 260px; margin-top: 30px;">
# <button class="bold check-avail" id="id-send-message-button" style="cursor: pointer; height: 50px; width: 260px; font-size: 1.20em;">Check Availability</button>
# </div>
# <div class="font-size-90" id="id-contact-form-error" style="text-align: center; margin-top: 15px; color: #a80000"></div>
# </input></input></form>
# </div>
# <div id="id-contact-form-success" style="margin-top: 25px; margin-left: 40px; margin-right: 40px;">
# <table style="margin-left: auto; margin-right: auto;">
# <tr>
# <td style="border-bottom: 1px solid #bbbbbb; border-top: 1px solid #bbbbbb; height: 213px; vertical-align: middle; text-align: center; padding-left: 20px; padding-right: 20px;">
# <img alt="Checkmark - Success" src="/images/ok-check-green.png" style="height: 25px; width: 32px"/>
# <div class="" id="id-contact-form-success-text" style="color: #106d00; margin-top: 15px; font-size: 15px;">
# </div>
# </td>
# </tr>
# </table>
# <table style="margin-left: auto; margin-right: auto; margin-top: 30px;">
# <tr>
# <td>
# <button class="bold check-avail" id="contact-listing-close" style="cursor: pointer; height: 50px; width: 120px; font-size: 1.20em;">Close</button>
# </td>
# </tr>
# </table>
# </div>
# <div id="fb_conversion_pixel"></div>
# </div>
# </div>
# <script type="text/javascript">
#
#
#   function contact_listing_show(region, listing_id, title) {
#     $("#contact-listing-overlay").show();
#     $("#contact-listing").show();
#
#     $("#listing-img").attr("src", $("#listing-" + listing_id + "-img").attr("src"));
#     $("#listing-img").attr("alt", $("#listing-" + listing_id + "-img").attr("alt"));
#     $("#listing-title").html($("#listing-" + listing_id + "-title").html());
#     $("#listing-neighborhoods").html($("#listing-" + listing_id + "-neighborhoods").html());
#     $("#listing-price").html($("#listing-" + listing_id + "-price").html());
#     $("#listing-hopscore").html($("#listing-" + listing_id + "-hopscore").html());
#
#     $("#use_region").attr('value', region);
#     $("#contact_listing_id").attr('value', listing_id);
#     $("#contact-listing-title").html(title);
#
#     $("#id-contact-form-success").hide();
#     $("#id-contact-form-wrapper").show();
#     $("#id-contact-form-error").html('');
#
#     $("#renter_name").focus();
#   }
#
#   $(function() {
#     $("#contact-listing").click(function(e) {
#       e.stopPropagation();
#     });
#
#     $("#contact-listing-overlay").click(function() {
#       $("#contact-listing-overlay").css('display', 'none');
#       $("#contact-listing").css('display', 'none');
#     });
#
#     $("#contact-listing-close").click(function() {
#       $("#contact-listing-overlay").css('display', 'none');
#       $("#contact-listing").css('display', 'none');
#     });
#
#     $("#id-send-message-button").click(function() {
#       Messages.send_web_browse();
#       return false;
#     });
#
#   });
#
#
# </script>
# <div id="hopscore-overlay" style="display: none; position: absolute; top: -18px; left: 62px; cursor: default; background-color: #ffffff; text-align: left; z-index: 100000; width: 240px; height: 180px; border: 1px solid #0091ff;">
# <div style="padding: 12px 15px 10px 15px;">
# <div class="font-size-85 bold">
# HopScore
# </div>
# <div class="font-size-80" style="margin-top: 6px;">
# This rating is a quick way of gauging a listing's quality.
# </div>
# <div id="stat-bars" style="width: 210px; margin-top: 15px;">
# <div class="font-size-80 color-fg-black">
# <div id="stat-freshness-num" style="float: right;"></div>
# Freshness
# </div>
# <div style="width: 210px; height: 2px; background-color: #cccccc; z-index: 100; margin-top: 1px;">
# <div id="stat-freshness-bar" style="width: 50%; height: 2px; background: linear-gradient(to right, #23a0ff, #23a0ff); z-index: 200;"></div>
# </div>
# <div class="font-size-80 color-fg-black" style="margin-top: 10px;">
# <div id="stat-quality-num" style="float: right;"></div>
# Listing Quality
# </div>
# <div style="width: 210px; height: 2px; background-color: #cccccc; z-index: 100; margin-top: 1px;">
# <div id="stat-quality-bar" style="width: 50%; height: 2px; background: linear-gradient(to right, #23a0ff, #23a0ff); z-index: 200;"></div>
# </div>
# <div class="font-size-80 color-fg-black" style="margin-top: 10px;">
# <div id="stat-manager-num" style="float: right;"></div>
# Manager Reputation
# </div>
# <div style="width: 210px; height: 2px; background-color: #cccccc; z-index: 100; margin-top: 1px;">
# <div id="stat-manager-bar" style="width: 50%; height: 2px; background: linear-gradient(to right, #23a0ff, #23a0ff); z-index: 200;"></div>
# </div>
# </div>
# </div>
# </div>
# <script>
#
#   $(function() {
#     $(".hopscore-link").hover(function() {
#       var freshness = $(this).attr('fs');
#       var quality = $(this).attr('qs');
#       var manager = $(this).attr('ms');
#
#       $("#stat-freshness-bar").css("width", freshness + "%");
#       $("#stat-quality-bar").css("width", quality + "%");
#       $("#stat-manager-bar").css("width", manager + "%");
#
#       $("#stat-freshness-num").html(freshness + "%");
#       $("#stat-quality-num").html(quality + "%");
#       $("#stat-manager-num").html(manager + "%");
#
#       $("#hopscore-overlay").appendTo($(this).parent().parent()).show();
#     },
#     function() {
#       $("#hopscore-overlay").hide();
#     });
#   });
#
# </script>
# <div class="nav-footer" style="background-color: #2a3136;">
# <div class="col-1">
# <div>
# <div class="nav-footer-left-col">
# <div>
# <div class="bold font-size-90" style="padding-bottom: 15px; color: #ffffff;">
# Company
# </div>
# <div class="font-size-85" style="color: #ffffff;">
# <div>
# <a href="/about" style="text-decoration: none; color: #dddddd;">About</a>
# </div>
# <div style="padding-top: 6px;">
# <a href="/press" style="text-decoration: none; color: #dddddd;">Press</a>
# </div>
# <div style="padding-top: 6px;">
# <a href="/terms#privacy" style="text-decoration: none; color: #dddddd;">Privacy</a>
# </div>
# <div style="padding-top: 6px; padding-bottom: 25px;">
# <a href="/terms" style="text-decoration: none; color: #dddddd;">Terms</a>
# </div>
# </div>
# </div>
# <div>
# <div class="bold font-size-90" style="padding-bottom: 15px; color: #ffffff;">
# Renters
# </div>
# <div class="font-size-85" style="color: #ffffff;">
# <div>
# <a href="/guides/nyc/how-to-rent-an-apartment-in-nyc" style="text-decoration: none; color: #dddddd;">Renter's Guide</a>
# </div>
# <div style="padding-top: 6px;">
# <a href="/qa" style="text-decoration: none; color: #dddddd;">Help and Answers</a>
# </div>
# <div style="padding-top: 6px; padding-bottom: 25px;">
# <a href="/blog" style="text-decoration: none; color: #dddddd;">Blog</a>
# </div>
# </div>
# </div>
# </div>
# <div class="nav-footer-right-col">
# <div>
# <div class="bold font-size-90" style="padding-bottom: 15px; color: #ffffff;">
# Discover
# </div>
# <div class="font-size-85" style="color: #ffffff;">
# <div>
# <a href="/studies" style="text-decoration: none; color: #dddddd;">Research and Studies</a>
# </div>
# <div style="padding-top: 6px; padding-bottom: 25px;">
# <a href="/rental-stats-and-trends" style="text-decoration: none; color: #dddddd;">Stats and Trends</a>
# </div>
# </div>
# </div>
# <div>
# <div class="bold font-size-90" style="padding-bottom: 15px; color: #ffffff;">
# Jobs
# </div>
# <div class="font-size-85" style="color: #ffffff;">
# <div style="padding-bottom: 25px;">
# <a href="/jobs" style="text-decoration: none; color: #dddddd;">We're Hiring!</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="nav-footer-info-clear"></div>
# <div class="nav-footer-info">
# <div class="nav-footer-info-terms font-size-85" style="color: #ffffff;">
# <div>
# <a href="https://itunes.apple.com/us/app/renthop-apartments-for-rent/id726232206">
# <img alt="Download the RentHop App" src="/images/appstore-badge.png" style="width: 135px; height: 40px;"/>
# </a>
# </div>
# </div>
# </div>
# <div style="clear: both;"></div>
# </div>
# </div>
# <div style="background-color: #202628; text-align: center; padding: 25px 0px 25px 0px;">
# <div style="display: inline-block;"><img alt="Fair Housing and Equal Opportunity" src="/images/fh.png" style="width: 16px; height: 14px;"/></div><div class="font-size-85" style="display: inline-block; color: #ffffff; margin-left: 5px;">Fair Housing and Equal Opportunity</div>
# <div class="font-size-85 bold" style="color: #ffffff; margin-top: 3px;">© 2009 - 2017 RentHop.com™</div>
# </div>
# <script src="/js/renthop.js?20170601"></script>
# <script>ListingsSearch.loaded_search_type = '1';
#                                              MapSelector.load("New York City, NY", '1', '6');
#                                              ListingsSearch.load('40.74773', '-73.977265');</script>
# <script>
#
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-5221211-1', 'auto');
#   ga('require', 'linkid', 'linkid.js');
#   ga('require', 'displayfeatures');
#   ga('send', 'pageview');
#
# </script>
# <script type="text/javascript">
#
# var clicky_site_ids = clicky_site_ids || [];
# clicky_site_ids.push(134586);
# (function() {
#   var s = document.createElement('script');
#   s.type = 'text/javascript';
#   s.async = true;
#   s.src = '//static.getclicky.com/js';
#   ( document.getElementsByTagName('head')[0] || document.getElementsByTagName('body')[0] ).appendChild( s );
# })();
# </script>
# <noscript><p><img alt="Clicky" height="1" src="//in.getclicky.com/134586ns.gif" width="1"/></p></noscript>
# <div style="display:none;">
# <img alt="Quantcast" border="0" height="1" src="//pixel.quantserve.com/pixel/p-5416y2OiuORCw.gif" width="1"/>
# </div>
# <script>
#
#
#   function init() {
#     var imgDefer = document.getElementsByTagName('img');
#     for (var i=0; i<imgDefer.length; i++) {
#       if(imgDefer[i].getAttribute('data-src')) {
#         imgDefer[i].setAttribute('src',imgDefer[i].getAttribute('data-src'));
#       }
#     }
#   }
#   window.onload = init;
#
#
# </script>
# <div id="fb-root"></div>
# <script>
#   (function(d){
#      var js, id = 'facebook-jssdk', ref = d.getElementsByTagName('script')[0];
#      if (d.getElementById(id)) {return;}
#      js = d.createElement('script'); js.id = id; js.async = true;
#      js.src = "//connect.facebook.net/en_US/all.js";
#      ref.parentNode.insertBefore(js, ref);
#   }(document));
# </script>
# </input></body>
# </html>

# %%
data = {'price': price,'listing_id':listing_id,'hopscore':hopscore,'street_address':street_address,'neighborhoods': neighborhoods,
       'expert': expert,'bedroom':bedroom, 'bathroom':bathroom,'description': description,'median_price':median_price,
       'num_transportation':num_transportation,'photo': photo_link,'Amenities': Amenities,'No Fee':noFee,'transportation':trans,}
#         'latitude':latitude,'longitude':longitude
# There is something wrong with longitude and latitude
Rent_house = pd.DataFrame.from_dict(data = data)
Rent_house
# Out:
#                                              Amenities  No Fee bathroom  \
# 0    [No Fee, Floorplans Available, Doorman, Elevat...       1        1
# 1    [Swimming Pool, Doorman, Fitness Center, Dogs ...       0        2
# 2    [Exclusive, Reduced Fee, Cats Allowed, Dogs Al...       0        1
# 3    [Doorman, Fitness Center, Elevator, Balcony, P...       0        1
# 4    [Dining Room, Laundry in Building, Laundry in ...       0        1
# 5    [Pre-War, Dishwasher, Hardwood Floors, Granite...       0        1
# 6    [No Fee, Swimming Pool, Roof Deck, Doorman, El...       1        1
# 7    [No Fee, Doorman, Elevator, Fitness Center, Te...       1        1
# 8    [Roof Deck, Doorman, Elevator, Fitness Center,...       0        1
# 9    [Hardwood Floors, Granite Kitchen, High Ceilin...       0        1
# 10   [No Fee, Controlled Access, Intercom System, S...       1        1
# 11   [No Fee, Laundry In Building, Laundry On Floor...       1        1
# 12   [No Fee, Doorman, Elevator, Fitness Center, Ce...       1        1
# 13   [No Fee, Doorman, Elevator, Fitness Center, Pr...       1        1
# 14   [No Fee, Swimming Pool, Roof Deck, Doorman, El...       1        1
# 15   [No Fee, Pre-War, Laundry in Building, Laundry...       1        1
# 16   [Roof Deck, Doorman, Elevator, Fitness Center,...       0        2
# 17   [Elevator, Loft, Laundry in Building, Hardwood...       0        1
# 18                                            [No Fee]       1        1
# 19                                                  []       0        1
# 20   [Cats Allowed, Dogs Allowed, Doorman, Elevator...       0        1
# 21   [No Fee, Swimming Pool, Roof Deck, Doorman, El...       1        1
# 22   [No Fee, Balcony, Doorman, Elevator, Terrace, ...       1        1
# 23                                  [No Fee, Elevator]       1        3
# 24                       [Pre-War, Brownstone, Subway]       0        1
# 25                       [Pre-War, Brownstone, Subway]       0        1
# 26   [No Fee, Floorplans Available, Exclusive, Door...       1        1
# 27              [Elevator, Cats Allowed, Dogs Allowed]       0        2
# 28   [No Fee, Doorman, Fitness Center, Laundry in B...       1        1
# 29   [No Fee, Private Outdoor Space, Cats Allowed, ...       1        1
# ..                                                 ...     ...      ...
# 502  [No Fee, Doorman, Private Outdoor Space, High-...       1        2
# 503  [No Fee, Elevator, Garden/Patio, Terrace, Dish...       1        1
# 504  [No Fee, Doorman, Elevator, Fitness Center, La...       1        2
# 505  [Roof Deck, Doorman, Elevator, Fitness Center,...       0        1
# 506  [No Fee, Roof Deck, Dining Room, Doorman, Elev...       1        2
# 507             [Pre-War, Dishwasher, Hardwood Floors]       0        1
# 508  [Cats Allowed, Dogs Allowed, Laundry In Buildi...       0        1
# 509   [Loft, Pre-War, Laundry in Building, Brownstone]       0        1
# 510  [No Fee, Roof Deck, Doorman, Elevator, Fitness...       1        2
# 511  [Floorplans Available, Doorman, Elevator, Fitn...       0        1
# 512  [No Fee, Roof Deck, Doorman, Elevator, Fitness...       1        1
# 513  [No Fee, Floorplans Available, Doorman, Elevat...       1        1
# 514  [No Fee, Laundry In Unit, Parking Space, Cats ...       1        1
# 515                                                 []       0        1
# 516  [No Fee, Elevator, Hardwood Floors, High Ceili...       1        1
# 517  [No Fee, Laundry In Unit, Cats Allowed, Dogs A...       1        1
# 518  [No Fee, Roof Deck, Doorman, Elevator, Fitness...       1        1
# 519  [No Fee, Roof Deck, Doorman, Elevator, Fitness...       1        1
# 520  [Floorplans Available, Laundry in Building, Ha...       0        1
# 521  [Floorplans Available, Roof Deck, Balcony, Doo...       0        1
# 522  [No Fee, Doorman, Elevator, Fitness Center, La...       1        1
# 523  [Dishwasher, Renovated, Laundry in Building, D...       0        1
# 524  [No Fee, Roof Deck, Doorman, Elevator, Fitness...       1        2
# 525  [No Fee, Floorplans Available, Doorman, Elevat...       1        1
# 526  [No Fee, Private Outdoor Space, Central Heat A...       1        2
# 527     [No Fee, Elevator, Cats Allowed, Dogs Allowed]       1        1
# 528  [Furnished, Common Outdoor Space, Laundry In U...       0        1
# 529  [No Fee, Hardwood Floors, Laundry In Building,...       1        1
# 530  [Exclusive, Renovated, City Views, Pet Friendl...       0        1
# 531                                                 []       0        1
#
#     bedroom                                        description  \
# 0         1  \nNewly renovated studio in FiDi, NO BROKER FE...
# 1         2  \nThis Spacious Two Bedroom Two BathFeatures l...
# 2         1  \nSpacious Sunny Big One Bedroom with Direct H...
# 3         1  \nCooperCooper.com :: Listing ID #8AA.nn44; Ac...
# 4         2  \nLocated in trendy Nolita, this gorgeous true...
# 5         1  \nI have total market coverage of Manhattan an...
# 6         1  \nSo Close to Manhattan, it's only 2 stops fur...
# 7         1  \nThis building offers studio, alcove studio, ...
# 8         1  \nApartment Features; * High Ceilings!* An Abu...
# 9         1  \nAbsolutely stunning and newly renovated true...
# 10        1  \nThis no fee, renovated 1 BR 1 baths and 2 ro...
# 11        1  \nNO FEE! NO FEE! NO FEE!\n\nDESCRIPTION:\n*Ne...
# 12        2  \n_+_+_+_+_+_ GREAT LOCATION KIPS BAY/GRAMERCY...
# 13        1  \nThe residences of this building are as varie...
# 14        1  \nNO FEE.This exquisitely designed studio apar...
# 15        1  \nNo Fee.Excellent TRUE one bedroom in prime W...
# 16        2  \nNO BROKER FEES. - Hardwood floors- Great vie...
# 17        1  \nJust Listed!! Fantastic Location West 13th S...
# 18        1  \nModern apartment on Nostrand Ave in the HEAR...
# 19        2  \nIDEAL SHARE!!! Very Spacious one bedroom apa...
# 20        1  \n*NO FEE*\n*ONE MONTH FREE on 13 month lease,...
# 21        1  \nAPARTMENTS FEATURES:* Exposed kitchens overl...
# 22        1  \nIt Features a new updated kitchen with dishw...
# 23        3                                                 \n
# 24        4  \nFantastic Location A multitude of daily conv...
# 25        4  \nGREAT LOCATION 4 BEDROOMS 1 FULL BATHS ON W1...
# 26        1  \n\n       Renoir House provides the quintesse...
# 27        2                                                 \n
# 28        1  \n1 MONTH FREE AND 100% NO FEE !!!! SPECIAL on...
# 29        1  \nEnjoy this Beautiful 317 FT private terrace....
# ..      ...                                                ...
# 502       3  \n\n       Our thoughts: Incredible interiors ...
# 503       3  \nPrice Drop!This renovated 3 bedroom apartmen...
# 504       2  \nLive in this luxury beautiful building in th...
# 505       4  \nIncredible apartment in our luxury doorman b...
# 506       3  \nNO BROKER FEE!! PLUS 1 Month Free!! Amazing ...
# 507       1  \nActual photosGut renovated, spacious and bri...
# 508       1  \nSpacious Bright South Facing Studio Loft wit...
# 509       1  \nApartment is conveniently located to mass tr...
# 510       2  \nDon't miss on this Gorgeous Apartment! This ...
# 511       1  \n\n       ***NO FEE****Spacious studio with m...
# 512       2  \n____________________________________________...
# 513       1  \n\n       NO FEE/ Amazing location!Spacious s...
# 514       1  \nDoorman, Elevator, Health Club, Pool, Subway...
# 515       2  \nCall or text Brett at (917) 397-4544 to view...
# 516       1  \nTrue 3 bedroom 1 bath with queens sized bedr...
# 517       2  \n**No Fee & 2 Months Free Rent**\n\nModern 2 ...
# 518       1  \nBright Corner 1 bedroom with hardwood floors...
# 519       1  \nBright Corner 1 bedroom with hardwood floors...
# 520       1  \nThis gorgeous apartment is priced perfectly ...
# 521       1  \nNO BROKER FEES. Located between Manhattan's ...
# 522       1  \nThis renovated studio features blonde hardwo...
# 523       2  \n\n       **NO FEE and 1 MONTH FREE**You can'...
# 524       4  \nLOW FEE!!!***HUGE 4BR 2BA***24HR DM***GYM***...
# 525       1  \nGorgeous, sun drenched one bedroom apartment...
# 526       2  \n\n       The pinnacle of high tone, stylish ...
# 527       1  \n\n*No Fee* Center of West Village, this one ...
# 528       1  \nAvailable immediately upon board approval. M...
# 529       3  \n3 Bed / 1 Bath in Bushwick Brooklyn.\n  \nBe...
# 530       3  \n\n       3 Bed / 1 Bath in Powers Street. Pe...
# 531       1  \nCall or text Brett at (917) 397-4544 to view...
#
#                         expert  hopscore  listing_id median_price  \
# 0                            0      73.8     9024150       $2,600
# 1                            0      73.8     8998634       $5,575
# 2                            0      73.8     9038621       $3,325
# 3                            0      73.8     9039372       $2,550
# 4                            0      73.8     8787948       $3,975
# 5                            0      73.8     9011220       $2,750
# 6     Downtown Brooklyn Expert      73.8     8964842       $2,450
# 7                            0      73.8     8960833       $3,175
# 8                            0      73.8     8919927       $3,100
# 9                            0      73.8     8931595       $3,200
# 10                           0      73.8     9025381       $2,275
# 11                           0      73.8     8722017       $2,275
# 12                           0      73.8     8774208       $3,300
# 13                           0      73.8     8974088       $2,600
# 14                           0      73.8     9040169       $2,600
# 15                           0      73.8     8939422       $3,450
# 16                           0      73.8     9000125       $5,700
# 17                           0      73.8     8924365       $2,600
# 18                           0      73.8     8708891       $2,275
# 19                           0      73.8     8819906       $3,175
# 20                           0      73.7     8779462       $2,600
# 21                           0      73.8     8785854       $2,650
# 22                           0      73.7     8893732       $3,750
# 23                           0      73.7     7684473      $10,000
# 24                           0      73.7     8899631       $4,650
# 25                           0      73.7     8900740       $4,650
# 26                           0      73.7     8942666       $2,625
# 27                           0      73.8     8609457       $6,650
# 28                           0      73.7     9002529       $2,450
# 29         Midtown East Expert      73.7     6358778       $3,300
# ..                         ...       ...         ...          ...
# 502                          0      73.7     7163429       $3,875
# 503                          0      73.7     9037797       $4,575
# 504                          0      73.7     8675896       $5,700
# 505                          0      73.7     8711536            0
# 506                          0      73.7     8973449       $5,875
# 507                          0      73.7     8600816       $3,450
# 508     Upper West Side Expert      73.7     8836483       $2,825
# 509                          0      73.7     8618175       $2,375
# 510  Financial District Expert      73.7     8824269       $5,175
# 511                          0      73.7     8812231       $2,600
# 512                          0      73.7     8953188       $3,700
# 513                          0      73.7     8684389       $2,600
# 514                          0      73.7     7117016       $3,650
# 515                          0      73.7     8956891       $1,625
# 516                          0      73.7     8851977       $2,450
# 517                          0      73.7     8728700       $4,200
# 518                          0      73.7     9043609       $2,375
# 519                          0      73.7     9043600       $2,375
# 520                          0      73.7     9000279       $2,825
# 521                          0      73.7     8913726       $3,175
# 522                          0      73.7     9000878       $2,625
# 523                          0      73.7     8763066       $3,775
# 524         Murray Hill Expert      73.7     9032917       $6,000
# 525                          0      73.7     9036400       $3,325
# 526                          0      73.7     8638615       $2,900
# 527                          0      73.7     8816712       $3,450
# 528                          0      73.7     5603181       $3,275
# 529                          0      73.7     8718345       $2,975
# 530                          0      73.7     8444264       $3,825
# 531                          0      73.7     8962081       $2,800
#
#                                          neighborhoods  num_transportation  \
# 0    Financial District, Downtown Manhattan, Manhattan                  25
# 1       Theater District, Midtown Manhattan, Manhattan                  23
# 2     Battery Park City, Downtown Manhattan, Manhattan                  14
# 3            Murray Hill, Midtown Manhattan, Manhattan                  20
# 4                NoLita, Downtown Manhattan, Manhattan                  12
# 5            Murray Hill, Midtown Manhattan, Manhattan                  20
# 6    Downtown Brooklyn, Northwestern Brooklyn, Broo...                  21
# 7    Financial District, Downtown Manhattan, Manhattan                  15
# 8    Brooklyn Heights, Northwestern Brooklyn, Brooklyn                  20
# 9     Greenwich Village, Downtown Manhattan, Manhattan                  23
# 10           Crown Heights, Central Brooklyn, Brooklyn                   8
# 11     Bedford-Stuyvesant, Northern Brooklyn, Brooklyn                   7
# 12              Kips Bay, Midtown Manhattan, Manhattan                  16
# 13   Financial District, Downtown Manhattan, Manhattan                   9
# 14   Financial District, Downtown Manhattan, Manhattan                  14
# 15         West Village, Downtown Manhattan, Manhattan                  18
# 16   Brooklyn Heights, Northwestern Brooklyn, Brooklyn                  20
# 17         West Village, Downtown Manhattan, Manhattan                  20
# 18           Crown Heights, Central Brooklyn, Brooklyn                   8
# 19   Turtle Bay, Midtown East, Midtown Manhattan, M...                  17
# 20   Financial District, Downtown Manhattan, Manhattan                   9
# 21           Williamsburg, Northern Brooklyn, Brooklyn                   9
# 22   Lincoln Square, Upper West Side, Upper Manhatt...                  14
# 23   Carnegie Hill, Upper East Side, Upper Manhatta...                   9
# 24   Little Senegal, Central Harlem, Upper Manhatta...                  10
# 25   Little Senegal, Central Harlem, Upper Manhatta...                  10
# 26         Upper East Side, Upper Manhattan, Manhattan                  14
# 27   Carnegie Hill, Upper East Side, Upper Manhatta...                   8
# 28   Hunters Point, Long Island City, Northwestern ...                  10
# 29   Turtle Bay, Midtown East, Midtown Manhattan, M...                  17
# ..                                                 ...                 ...
# 502          Williamsburg, Northern Brooklyn, Brooklyn                   7
# 503  Alphabet City, East Village, Downtown Manhatta...                  13
# 504  Brooklyn Heights, Northwestern Brooklyn, Brooklyn                  20
# 505  Alphabet City, East Village, Downtown Manhatta...                   9
# 506              Chelsea, Midtown Manhattan, Manhattan                  18
# 507              Chelsea, Midtown Manhattan, Manhattan                  11
# 508        Upper West Side, Upper Manhattan, Manhattan                  12
# 509        Upper West Side, Upper Manhattan, Manhattan                  12
# 510  Financial District, Downtown Manhattan, Manhattan                  18
# 511  Financial District, Downtown Manhattan, Manhattan                  15
# 512              Chelsea, Midtown Manhattan, Manhattan                  18
# 513  Financial District, Downtown Manhattan, Manhattan                  15
# 514        Civic Center, Downtown Manhattan, Manhattan                  25
# 515                   North Lindenhurst, Babylon, Town                   0
# 516  Rose Hill, Kips Bay, Midtown Manhattan, Manhattan                  16
# 517       Fort Greene, Northwestern Brooklyn, Brooklyn                  18
# 518      Long Island City, Northwestern Queens, Queens                  12
# 519      Long Island City, Northwestern Queens, Queens                  12
# 520        Upper West Side, Upper Manhattan, Manhattan                   6
# 521              Chelsea, Midtown Manhattan, Manhattan                  13
# 522        Upper East Side, Upper Manhattan, Manhattan                  14
# 523        Gramercy Park, Midtown Manhattan, Manhattan                  17
# 524          Murray Hill, Midtown Manhattan, Manhattan                  20
# 525   Battery Park City, Downtown Manhattan, Manhattan                   8
# 526                     Commonwealth, Brighton, Boston                   0
# 527        West Village, Downtown Manhattan, Manhattan                  20
# 528       Hell's Kitchen, Midtown Manhattan, Manhattan                  23
# 529              Bushwick, Northern Brooklyn, Brooklyn                   8
# 530  East Williamsburg, Williamsburg, Northern Broo...                   9
# 531  Turtle Bay, Midtown East, Midtown Manhattan, M...                  17
#
#                                                  photo    price  \
# 0    [https://photos.renthop.com/7/9024150_8e34db33...   $2,550
# 1    [https://photos.renthop.com/7/8998634_b3204a19...   $5,657
# 2    [https://photos.renthop.com/7/9038621_63e340ab...   $3,600
# 3    [https://photos.renthop.com/7/9039372_7dc83c9b...   $3,563
# 4    [https://photos.renthop.com/7/8787948_28ae4cbc...   $3,896
# 5    [https://photos.renthop.com/7/9011220_9ba680cb...   $2,450
# 6    [https://photos.renthop.com/7/8964842_0797a67a...   $2,525
# 7    [https://photos.renthop.com/7/8960833_7d47e1a0...   $3,725
# 8    [https://photos.renthop.com/7/8919927_5b328d71...   $2,995
# 9    [https://photos.renthop.com/7/8931595_f53bd728...   $2,700
# 10   [https://photos.renthop.com/7/9025381_d9b95e83...   $2,000
# 11   [https://photos.renthop.com/7/8722017_2c7c91e7...   $2,300
# 12   [https://photos.renthop.com/7/8774208_fbc04171...   $3,575
# 13   [https://photos.renthop.com/7/8974088_f5ace65e...   $2,755
# 14   [https://photos.renthop.com/7/9040169_3598cbbd...   $2,700
# 15   [https://photos.renthop.com/7/8939422_d0e69233...   $3,295
# 16                                                  []   $5,070
# 17   [https://photos.renthop.com/7/8924365_b9744636...   $2,525
# 18   [https://photos.renthop.com/7/8708891_0c0256d1...   $2,650
# 19   [https://photos.renthop.com/7/8819906_26ec7450...   $2,250
# 20   [https://photos.renthop.com/7/8779462_563843db...   $2,180
# 21   [https://photos.renthop.com/7/8785854_5d38d439...   $2,700
# 22   [https://photos.renthop.com/7/8893732_e9746bd0...   $3,475
# 23   [https://photos.renthop.com/7/7684473_bb6363a8...  $21,500
# 24   [https://photos.renthop.com/7/8899631_8a7a23aa...   $4,650
# 25   [https://photos.renthop.com/7/8900740_cdc3f93e...   $4,650
# 26   [https://photos.renthop.com/7/8942666_6a8ff9c1...   $2,950
# 27                                                  []   $6,800
# 28   [https://photos.renthop.com/7/9002529_a436a1b2...   $2,300
# 29   [https://photos.renthop.com/7/6358778_51111a40...   $4,600
# ..                                                 ...      ...
# 502  [https://photos.renthop.com/7/7163429_a11b065a...   $7,100
# 503  [https://photos.renthop.com/7/9037797_5d90e851...   $4,495
# 504  [https://photos.renthop.com/7/8675896_fa4fa8ba...   $4,930
# 505  [https://photos.renthop.com/7/8711536_6e2e70e9...   $5,525
# 506  [https://photos.renthop.com/7/8973449_f25c22b5...   $4,500
# 507  [https://photos.renthop.com/7/8600816_29b70bf4...   $3,099
# 508  [https://photos.renthop.com/7/8836483_a417a2fa...   $2,475
# 509  [https://photos.renthop.com/7/8618175_02de4c0d...   $2,475
# 510  [https://photos.renthop.com/7/8824269_b6cb2fce...   $7,000
# 511  [https://photos.renthop.com/7/8812231_0f4dbaf8...   $2,675
# 512  [https://photos.renthop.com/7/8953188_287fe2b8...   $3,150
# 513  [https://photos.renthop.com/7/8684389_c5d1daa3...   $2,725
# 514  [https://photos.renthop.com/7/6676063_12dfb6ec...   $3,395
# 515  [https://photos.renthop.com/7/8956891_f1131443...   $4,000
# 516  [https://photos.renthop.com/7/8851977_cc849075...   $4,695
# 517  [https://photos.renthop.com/7/8728700_2f92453c...   $4,231
# 518  [https://photos.renthop.com/7/9043609_a34f2c60...   $2,288
# 519  [https://photos.renthop.com/7/9043600_c101e8b3...   $2,298
# 520  [https://photos.renthop.com/7/9000279_22b89d58...   $2,400
# 521                                                 []   $3,990
# 522  [https://photos.renthop.com/7/9000878_3c3392b1...   $3,200
# 523  [https://photos.renthop.com/7/8763066_36920c07...   $3,687
# 524  [https://photos.renthop.com/7/9032917_d235d0e7...   $5,900
# 525  [https://photos.renthop.com/7/9036400_1bb2c38c...   $3,300
# 526  [https://photos.renthop.com/7/8638615_cbe58bc2...   $5,549
# 527  [https://photos.renthop.com/7/8816712_03b83cc3...   $3,550
# 528  [https://photos.renthop.com/7/5603181_3d33652b...   $4,200
# 529  [https://photos.renthop.com/7/8718345_4dd6ced3...   $3,210
# 530  [https://photos.renthop.com/7/8444264_e9b46739...   $2,475
# 531  [https://photos.renthop.com/7/8962081_cef0723a...   $3,995
#
#                    street_address  \
# 0                        Park Row
# 1                West 50th Street
# 2                380 Rector Place
# 3                East 34th Street
# 4                   Spring Street
# 5                  East 36 Street
# 6                        Gold St.
# 7                     Pine Street
# 8                     Clinton St.
# 9                West 11th Street
# 10                    Dean Street
# 11                 Hancock Street
# 12                       2nd Ave,
# 13                       Wall St.
# 14                       Gold St.
# 15                   Leroy Street
# 16                Montague Street
# 17               West 13th Street
# 18                Nostrand Avenue
# 19                 E 51 and 2 ave
# 20                 Exchange Place
# 21                      Union Ave
# 22               West 67th Street
# 23               1085 Park Avenue
# 24              West 115th Street
# 25              West 115th Street
# 26   225 East 63rd Street, Apt 1A
# 27               1225 Park Avenue
# 28               Center Boulevard
# 29                 49th & 2nd ave
# ..                            ...
# 502                      N 4th Pl
# 503                      E 3rd St
# 504                  Montague St.
# 505               East 7th Street
# 506                      W 34 St.
# 507                  Ninth Avenue
# 508                     West 73rd
# 509              West 75th Street
# 510                  Broad Street
# 511                   Wall Street
# 512                    W 34th St.
# 513                   Wall Street
# 514                 South Tribeca
# 515                    6th Street
# 516              East 30th Street
# 517                300 Ashland Pl
# 518                    Hunter St.
# 519                    Hunter St.
# 520              Amsterdam Avenue
# 521              West 29th Street
# 522                    E 63rd St.
# 523                    Park Ave S
# 524                    E 34th St.
# 525                 Battery Place
# 526                   Pier 4 Blvd
# 527                   Jane Street
# 528
# 529             Willoughby Avenue
# 530          82 Powers St, Apt 4L
# 531                       East 52
#
#                                         transportation
# 0    [2, 3, A, C, 4, 5, J, Z, 1, 2, 3, A, C, E, 2, ...
# 1    [C, E, N, Q, R, E, B, D, B, D, F, M, 1, 2, 3, ...
# 2           [1, 4, 5, R, J, Z, 2, 3, A, C, 4, 5, J, Z]
# 3    [6, 4, 5, 6, 7, S, N, R, B, D, F, M, 7, N, Q, ...
# 4                 [J, Z, 6, B, D, N, R, 6, B, D, F, M]
# 5    [6, 4, 5, 6, 7, S, B, D, F, M, 7, N, Q, R, B, ...
# 6    [F, A, C, R, F, 2, 3, A, C, 4, 5, J, Z, Q, R, ...
# 7        [2, 3, J, Z, 2, 3, A, C, 4, 5, J, Z, R, 4, 5]
# 8    [2, 3, 4, 5, R, 2, 3, A, C, R, F, 2, 3, A, C, ...
# 9    [1, 2, 3, F, M, L, A, C, E, B, D, F, M, 1, 4, ...
# 10                            [A, C, 3, A, S, 2, 5, S]
# 11                               [A, C, A, S, G, S, C]
# 12    [6, N, R, L, 4, 5, 6, N, Q, R, L, 4, 5, 6, 7, S]
# 13                         [2, 3, J, Z, R, 4, 5, 1, R]
# 14          [2, 3, 2, 3, A, C, 4, 5, J, Z, J, Z, R, 1]
# 15   [1, A, C, E, B, D, F, M, C, E, 1, 2, 3, F, M, ...
# 16   [2, 3, 4, 5, R, 2, 3, A, C, R, F, 2, 3, A, C, ...
# 17   [1, 2, 3, F, M, L, A, C, E, L, 1, A, C, E, B, ...
# 18                            [A, C, S, A, S, 2, 5, 3]
# 19   [E, 6, M, 4, 5, 6, N, Q, R, 4, 5, 6, 7, S, E, ...
# 20                         [2, 3, J, Z, R, 4, 5, 1, R]
# 21                         [G, L, L, G, M, J, Z, M, J]
# 22          [1, 1, 2, 3, 1, A, C, B, D, C, B, N, Q, R]
# 23                         [4, 5, 6, 6, C, B, N, Q, T]
# 24                      [C, B, 2, 3, A, C, B, D, 1, 6]
# 25                      [C, B, 2, 3, A, C, B, D, 1, 6]
# 26          [F, 4, 5, 6, N, Q, R, 6, N, Q, T, E, 6, M]
# 27                            [6, 4, 5, 6, C, B, 2, 3]
# 28                      [7, G, E, M, 7, G, N, Q, 7, F]
# 29   [E, 6, M, 4, 5, 6, 7, S, E, M, 4, 5, 6, N, Q, ...
# ..                                                 ...
# 502                              [L, G, G, L, M, J, Z]
# 503            [F, F, M, J, Z, L, J, Z, 6, B, D, F, M]
# 504  [2, 3, 4, 5, R, 2, 3, A, C, R, F, 2, 3, A, C, ...
# 505                        [L, F, F, M, J, Z, 6, N, R]
# 506  [A, C, E, 7, 1, 1, 2, 3, A, C, E, N, Q, R, 7, ...
# 507                  [C, E, 1, A, C, E, L, A, C, E, 7]
# 508               [C, B, 1, 1, A, C, B, D, N, Q, R, 6]
# 509               [C, B, 1, 1, A, C, B, D, 6, N, Q, R]
# 510  [4, 5, J, Z, R, 2, 3, A, C, 4, 5, J, Z, 2, 3, ...
# 511      [J, Z, 2, 3, R, 4, 5, 2, 3, A, C, 4, 5, J, Z]
# 512  [A, C, E, 7, 1, 1, 2, 3, A, C, E, N, Q, R, 7, ...
# 513      [J, Z, 2, 3, R, 4, 5, 2, 3, A, C, 4, 5, J, Z]
# 514  [R, 1, 2, 3, A, C, E, 2, 3, A, C, E, 4, 5, 6, ...
# 515                                                 []
# 516   [6, N, R, 4, 5, 6, 7, S, N, Q, R, B, D, F, M, L]
# 517  [G, 2, 3, 4, 5, N, Q, R, B, D, 2, 3, 4, 5, C, ...
# 518               [G, E, M, 7, G, N, Q, 7, E, R, M, F]
# 519               [G, E, M, 7, G, N, Q, 7, E, R, M, F]
# 520                                 [1, C, B, 1, 2, 3]
# 521            [N, R, N, Q, R, B, D, F, M, F, M, 6, 1]
# 522         [F, 4, 5, 6, N, Q, R, 6, N, Q, T, E, 6, M]
# 523  [6, 4, 5, 6, N, Q, R, L, N, R, L, 1, 2, 3, F, ...
# 524  [6, 4, 5, 6, 7, S, N, R, B, D, F, M, 7, N, Q, ...
# 525                           [1, 4, 5, 1, R, J, Z, R]
# 526                                                 []
# 527  [A, C, E, L, 1, 2, 3, F, M, L, 1, A, C, E, B, ...
# 528  [1, 2, 3, A, C, E, N, Q, R, 7, S, C, E, N, Q, ...
# 529                           [M, M, J, Z, J, L, M, J]
# 530                        [G, L, L, G, M, J, M, J, Z]
# 531  [E, 6, M, 4, 5, 6, N, Q, R, F, 4, 5, 6, 7, S, ...
#
# [532 rows x 15 columns]

# %%
Rent_house.to_csv('/Users/admin/Documents/renthop_house90.csv')

# %%
df11 = pd.read_csv('/Users/admin/Documents/renthop_house90.csv')
df11.shape
# Out:
# (532, 16)
